# %%
import pandas as pd
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
# 定义类别标签
labels = ["猫", "狗"]
# 定义数据（预测值和真实值）
y_true = ["猫", "猫", "猫", "猫", "猫", "猫", "狗", "狗", "狗", "狗"] 
y_pred = ["猫", "猫", "狗", "猫", "猫", "猫", "猫", "猫", "狗", "狗"]

# %%
# 得到混淆矩阵
matrix = confusion_matrix(y_true, y_pred, labels=labels)
print(matrix)
# Out:
# [[5 1]
#  [2 2]]

# %%
print(pd.DataFrame(matrix, columns=labels, index=labels))
# Out:
#    猫  狗
# 猫  5  1
# 狗  2  2

# %%
ax = sns.heatmap(matrix, annot=True, fmt='d', cmap="Greens")

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_true, y_pred)
print(accuracy)
# Out:
# 0.7

# %%
from sklearn.metrics import precision_score
precision = precision_score(y_true, y_pred, pos_label="猫")
print(precision)
precision = precision_score(y_true, y_pred, pos_label="狗")
print(precision)
# Out:
# 0.7142857142857143
# 0.6666666666666666

# %%
from sklearn.metrics import recall_score
recall = recall_score(y_true, y_pred, pos_label="猫")
print(recall)
recall = recall_score(y_true, y_pred, pos_label="狗")
print(recall)
# Out:
# 0.8333333333333334
# 0.5

# %%
from sklearn.metrics import f1_score
f1 = f1_score(y_true, y_pred, pos_label="猫")
print(f1)
f1 = f1_score(y_true, y_pred, pos_label="狗")
print(f1)
# Out:
# 0.7692307692307693
# 0.5714285714285714

# %%
from sklearn.metrics import classification_report
report = classification_report(y_true, y_pred, labels=labels, target_names=['猫', "狗"])
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            猫       0.71      0.83      0.77         6
#            狗       0.67      0.50      0.57         4
#
#     accuracy                           0.70        10
#    macro avg       0.69      0.67      0.67        10
# weighted avg       0.70      0.70      0.69        10
